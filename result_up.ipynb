# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S24.htm'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="300" http-equiv="refresh"/>
# <!-- Bootstrap CSS -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/custom.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet"/>
# <link href="img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link crossorigin="" href="css/leaflet.css" integrity="sha256-kLaT2GOSpHechhsozzB+flnD+zUyjE2LlfWPgU04xyI=" rel="stylesheet"/>
# ...

# %%
table = soup.find('table')

print(table)
# Out:
# <table class="table">
# <thead>
# <tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr class="tr">
# <td style="text-align:left">Samajwadi Party - SP</td>
# <td style="text-align:right">
# <a href="partywisewinresult-1680S24.htm">37</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">37</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Bharatiya Janata Party - BJP</td>
# <td style="text-align:right">
# <a href="partywisewinresult-369S24.htm">33</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
# ...

# %%
world_titles = table.find_all('th')

world_titles
# Out:
# [<th style="text-align: left;">Party</th>,
#  <th style="text-align:right">Won</th>,
#  <th style="text-align:right">Leading</th>,
#  <th style="text-align:right">Total</th>,
#  <th>Total</th>,
#  <th style="text-align:right">80</th>,
#  <th style="text-align:right">0</th>,
#  <th style="text-align:right">80</th>]

# %%
world_table_titles = [ title.text for title in world_titles ]

print(world_table_titles)
# Out:
# ['Party', 'Won', 'Leading', 'Total', 'Total', '80', '0', '80']

# %%
del world_table_titles [4:8]

print(world_table_titles)
# Out:
# ['Party', 'Won', 'Leading', 'Total']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Party, Won, Leading, Total]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
column_data
# Out:
# [<tr>
#  <th style="text-align: left;">Party</th>
#  <th style="text-align:right">Won</th>
#  <th style="text-align:right">Leading</th>
#  <th style="text-align:right">Total</th>
#  </tr>,
#  <tr class="tr">
#  <td style="text-align:left">Samajwadi Party - SP</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-1680S24.htm">37</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">37</td>
#  </tr>,
#  <tr class="tr">
#  <td style="text-align:left">Bharatiya Janata Party - BJP</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-369S24.htm">33</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
# ...

# %%
for row in column_data[1:6]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    #print(individual_row_data)
    length = len(df)
    df.loc[length] = individual_row_data
df
# Out:
#                                     Party Won Leading Total
# 0                    Samajwadi Party - SP  37       0    37
# 1            Bharatiya Janata Party - BJP  33       0    33
# 2          Indian National Congress - INC   6       0     6
# 3                 Rashtriya Lok Dal - RLD   2       0     2
# 4  Aazad Samaj Party (Kanshi Ram) - ASPKR   1       0     1

# %%
df.loc[len(df)] = ['Total', '175', '0', '175'] 
df
# Out:
#                                     Party  Won Leading Total
# 0                    Samajwadi Party - SP   37       0    37
# 1            Bharatiya Janata Party - BJP   33       0    33
# 2          Indian National Congress - INC    6       0     6
# 3                 Rashtriya Lok Dal - RLD    2       0     2
# 4  Aazad Samaj Party (Kanshi Ram) - ASPKR    1       0     1
# 5                                   Total  175       0   175

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_79a8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79a8e_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_79a8e_level0_col1" class="col_heading level0 col1" >Won</th>
#       <th id="T_79a8e_level0_col2" class="col_heading level0 col2" >Leading</th>
#       <th id="T_79a8e_level0_col3" class="col_heading level0 col3" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79a8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79a8e_row0_col0" class="data row0 col0" >Samajwadi Party - SP</td>
#       <td id="T_79a8e_row0_col1" class="data row0 col1" >37</td>
#       <td id="T_79a8e_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_79a8e_row0_col3" class="data row0 col3" >37</td>
#     </tr>
#     <tr>
#       <th id="T_79a8e_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
output_path = 'C:/Users/Kavisha/OneDrive/Desktop/pandas/assembly_constituency_up.csv'
df.to_csv(output_path, index=False)

print(f"DataFrame : {output_path}")
# Out:
# DataFrame : C:/Users/Kavisha/OneDrive/Desktop/pandas/assembly_constituency_up.csv
